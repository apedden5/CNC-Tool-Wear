# %% [markdown]
# ## Displaying Loaded data from 18 experiments and train

# %%
from src.data_preprocessing import load_experiments
# displaying experiment 1, 11, and 18 to ensure data loaded in properly

experiments = load_experiments()
display(experiments[0].head(6))

display(experiments[10].head(6))

display(experiments[17].head(6))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.data_preprocessing import load_experiments
#       2 # displaying experiment 1, 11, and 18 to ensure data loaded in properly
#       4 experiments = load_experiments()
#
# ModuleNotFoundError: No module named 'src'
